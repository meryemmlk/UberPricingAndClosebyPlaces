# %%
import os
import json
from shapely.geometry import Polygon
from numpy import random
from shapely.geometry import Point
import pandas as pd

# libraries for UBER API
from uber_rides.session import Session
from uber_rides.client import UberRidesClient

# libraries for take the capture date
from datetime import datetime, timedelta

# libraries for capture data each 4 min
import threading

# %%
from uber_rides.session import Session
session = Session(server_token="TZ9aAN7GMzp49djfXoMil2HJ7XxCs0Zwo8EWXd88")

from uber_rides.client import UberRidesClient
client = UberRidesClient(session)

# %%
places = [
  { "name": "Centennial Park",
  "location": [33.7603474,-84.3957012]},
  { "name": "Buckhead Bars",
  "location": [33.8439849,-84.3789694]},
  { "name": "Inman Park",
  "location": [33.7613676,-84.3623401]},
  { "name": "Stone Mountain",
  "location": [33.8053189,-84.1477255]},
  { "name": "Six Flags",
  "location": [33.7706408,-84.5537186]},
  { "name": "Statefarm Arena",
 "location": [33.7572891,-84.3963244]},
 { "name": "Zoo Atlanta",
 "location": [33.7327032,-84.3846396]},
 { "name": "Atlanta High Museum",
 "location": [33.7900632,-84.3877407]},
 { "name": "Fox Theater",
 "location": [33.7724591,-84.3879697]},
 { "name": "Virginia Highlands",
 "location": [33.7795027,-84.3757217]},
 { "name": "Shops at Buckhead",
 "location": [33.838031,-84.3821468]},
 { "name": "Emory University",
 "location": [33.7925239,-84.3261929]},
 { "name": "Georgia State University",
 "location": [33.7530724,-84.3874759]},
 { "name": "Spelman College",
 "location": [33.7463641,-84.4144874]},
 { "name": "Edgewood Bars",
 "location": [33.7544814,-84.3745674]},
  {"name": "Hartsfield Jackson Airport",
  "location": [33.6407282,-84.4277001]},
   {"name":"SunTrust Park",
   "location":[33.8908211,-84.4678309]},
   {"name":"Mercedes Benz Stadium",
   "location":[33.7554483,-84.400855]},
   {"name":"Lenox Square Mall",
    "location":[33.8462925,-84.3621419]},
   {"name":"Piedmont Park",
   "location":[33.7850856,-84.373803]}]
total_estimates = []
estimates = {}
#Global Learning Center GA TECH: 33.7762° N, 84.3895° W

for place in places:
    estimates = {}
    response = client.get_price_estimates(
        start_latitude=33.7762,
        start_longitude=-84.3895,
        end_latitude=place["location"][0],
        end_longitude=place["location"][1]
    )

    estimate = response.json.get('prices')
    #print(estimate)
    #estimate10
    estimates["place"] = place["name"]
    estimates["geometry"] = place["location"]
    autotimeinit = datetime.now()
    autotime = autotimeinit.strftime('%H: %M')
    estimates["autotime"] = autotime
    estimates["time"] = "20:00"
    estimates["value"] = estimate
    # last_hour_date_time = datetime.now() - timedelta(hours = 1)
    # list_datetime_capture.append(last_hour_date_time.strftime('%Y-%m-%d %H:%M:%S'))
    total_estimates.append(estimates)
total_estimates
# Out:
# [{'place': 'Centennial Park',
#   'geometry': [33.7603474, -84.3957012],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 1.52,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 10.0,
#     'low_estimate': 6.0,
#     'duration': 480,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 1.52,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 480,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 1.52,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 13.0,
#     'low_estimate': 10.0,
#     'duration': 480,
#     'estimate': '$10-13',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 1.52,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 14.0,
#     'low_estimate': 11.0,
#     'duration': 480,
#     'estimate': '$11-14',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 1.52,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 17.0,
#     'low_estimate': 13.0,
#     'duration': 480,
#     'estimate': '$13-17',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 1.52,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 28.0,
#     'low_estimate': 22.0,
#     'duration': 480,
#     'estimate': '$22-28',
#     'currency_code': 'USD'}]},
#  {'place': 'Buckhead Bars',
#   'geometry': [33.8439849, -84.3789694],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 8.88,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 16.0,
#     'low_estimate': 11.0,
#     'duration': 1020,
#     'estimate': '$11-15',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 8.88,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 16.0,
#     'low_estimate': 12.0,
#     'duration': 1020,
#     'estimate': '$12-16',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 8.88,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 32.0,
#     'low_estimate': 26.0,
#     'duration': 1020,
#     'estimate': '$26-32',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 8.88,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 35.0,
#     'low_estimate': 28.0,
#     'duration': 1020,
#     'estimate': '$28-35',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 8.88,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 49.0,
#     'low_estimate': 39.0,
#     'duration': 1020,
#     'estimate': '$39-49',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 8.88,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 66.0,
#     'low_estimate': 53.0,
#     'duration': 1020,
#     'estimate': '$53-66',
#     'currency_code': 'USD'}]},
#  {'place': 'Inman Park',
#   'geometry': [33.7613676, -84.3623401],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 2.78,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 720,
#     'estimate': '$6-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 2.78,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 720,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 2.78,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 17.0,
#     'low_estimate': 13.0,
#     'duration': 720,
#     'estimate': '$13-17',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 2.78,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 19.0,
#     'low_estimate': 14.0,
#     'duration': 720,
#     'estimate': '$14-19',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 2.78,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 24.0,
#     'low_estimate': 18.0,
#     'duration': 720,
#     'estimate': '$18-24',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 2.78,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 35.0,
#     'low_estimate': 28.0,
#     'duration': 720,
#     'estimate': '$28-35',
#     'currency_code': 'USD'}]},
#  {'place': 'Stone Mountain',
#   'geometry': [33.8053189, -84.1477255],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 27.79,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 36.0,
#     'low_estimate': 28.0,
#     'duration': 2280,
#     'estimate': '$28-35',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 27.79,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 37.0,
#     'low_estimate': 30.0,
#     'duration': 2280,
#     'estimate': '$30-37',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 27.79,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 81.0,
#     'low_estimate': 66.0,
#     'duration': 2280,
#     'estimate': '$66-81',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 27.79,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 86.0,
#     'low_estimate': 69.0,
#     'duration': 2280,
#     'estimate': '$69-86',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 27.79,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 127.0,
#     'low_estimate': 103.0,
#     'duration': 2280,
#     'estimate': '$103-127',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 27.79,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 164.0,
#     'low_estimate': 133.0,
#     'duration': 2280,
#     'estimate': '$133-164',
#     'currency_code': 'USD'}]},
#  {'place': 'Six Flags',
#   'geometry': [33.7706408, -84.5537186],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 14.42,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 20.0,
#     'low_estimate': 15.0,
#     'duration': 1440,
#     'estimate': '$15-19',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 14.42,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 20.0,
#     'low_estimate': 16.0,
#     'duration': 1440,
#     'estimate': '$16-20',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 14.42,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 47.0,
#     'low_estimate': 37.0,
#     'duration': 1440,
#     'estimate': '$37-47',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 14.42,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 50.0,
#     'low_estimate': 40.0,
#     'duration': 1440,
#     'estimate': '$40-50',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 14.42,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 72.0,
#     'low_estimate': 58.0,
#     'duration': 1440,
#     'estimate': '$58-72',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 14.42,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 95.0,
#     'low_estimate': 77.0,
#     'duration': 1440,
#     'estimate': '$77-95',
#     'currency_code': 'USD'}]},
#  {'place': 'Statefarm Arena',
#   'geometry': [33.7572891, -84.3963244],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 2.04,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 5.0,
#     'duration': 600,
#     'estimate': '$5-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 2.04,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 600,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 2.04,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 15.0,
#     'low_estimate': 11.0,
#     'duration': 600,
#     'estimate': '$11-15',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 2.04,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 16.0,
#     'low_estimate': 12.0,
#     'duration': 600,
#     'estimate': '$12-16',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 2.04,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 20.0,
#     'low_estimate': 15.0,
#     'duration': 600,
#     'estimate': '$15-20',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 2.04,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 31.0,
#     'low_estimate': 24.0,
#     'duration': 600,
#     'estimate': '$24-31',
#     'currency_code': 'USD'}]},
#  {'place': 'Zoo Atlanta',
#   'geometry': [33.7327032, -84.3846396],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 4.33,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 10.0,
#     'low_estimate': 6.0,
#     'duration': 720,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 4.33,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 10.0,
#     'low_estimate': 8.0,
#     'duration': 720,
#     'estimate': '$8-10',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 4.33,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 20.0,
#     'low_estimate': 16.0,
#     'duration': 720,
#     'estimate': '$16-20',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 4.33,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 22.0,
#     'low_estimate': 17.0,
#     'duration': 720,
#     'estimate': '$17-22',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 4.33,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 29.0,
#     'low_estimate': 23.0,
#     'duration': 720,
#     'estimate': '$23-29',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 4.33,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 42.0,
#     'low_estimate': 34.0,
#     'duration': 720,
#     'estimate': '$34-42',
#     'currency_code': 'USD'}]},
#  {'place': 'Atlanta High Museum',
#   'geometry': [33.7900632, -84.3877407],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 1.32,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 420,
#     'estimate': '$6-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 1.32,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 420,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 1.32,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 12.0,
#     'low_estimate': 9.0,
#     'duration': 420,
#     'estimate': '$9-12',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 1.32,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 14.0,
#     'low_estimate': 10.0,
#     'duration': 420,
#     'estimate': '$10-14',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 1.32,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 17.0,
#     'low_estimate': 13.0,
#     'duration': 420,
#     'estimate': '$13-17',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 1.32,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 28.0,
#     'low_estimate': 22.0,
#     'duration': 420,
#     'estimate': '$22-28',
#     'currency_code': 'USD'}]},
#  {'place': 'Fox Theater',
#   'geometry': [33.7724591, -84.3879697],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 0.31,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 240,
#     'estimate': '$6-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 0.31,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 240,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 0.31,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 11.0,
#     'low_estimate': 8.0,
#     'duration': 240,
#     'estimate': '$8-11',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 0.31,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 13.0,
#     'low_estimate': 10.0,
#     'duration': 240,
#     'estimate': '$10-13',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 0.31,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 17.0,
#     'low_estimate': 13.0,
#     'duration': 240,
#     'estimate': '$13-17',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 0.31,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 28.0,
#     'low_estimate': 22.0,
#     'duration': 240,
#     'estimate': '$22-28',
#     'currency_code': 'USD'}]},
#  {'place': 'Virginia Highlands',
#   'geometry': [33.7795027, -84.3757217],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 1.03,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 360,
#     'estimate': '$6-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 1.03,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 360,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 1.03,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 11.0,
#     'low_estimate': 8.0,
#     'duration': 360,
#     'estimate': '$8-11',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 1.03,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 13.0,
#     'low_estimate': 10.0,
#     'duration': 360,
#     'estimate': '$10-13',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 1.03,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 17.0,
#     'low_estimate': 13.0,
#     'duration': 360,
#     'estimate': '$13-17',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 1.03,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 28.0,
#     'low_estimate': 22.0,
#     'duration': 360,
#     'estimate': '$22-28',
#     'currency_code': 'USD'}]},
#  {'place': 'Shops at Buckhead',
#   'geometry': [33.838031, -84.3821468],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 6.49,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 13.0,
#     'low_estimate': 9.0,
#     'duration': 1020,
#     'estimate': '$9-12',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 6.49,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 14.0,
#     'low_estimate': 10.0,
#     'duration': 1020,
#     'estimate': '$10-14',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 6.49,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 27.0,
#     'low_estimate': 21.0,
#     'duration': 1020,
#     'estimate': '$21-27',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 6.49,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 29.0,
#     'low_estimate': 23.0,
#     'duration': 1020,
#     'estimate': '$23-29',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 6.49,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 40.0,
#     'low_estimate': 32.0,
#     'duration': 1020,
#     'estimate': '$32-40',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 6.49,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 55.0,
#     'low_estimate': 44.0,
#     'duration': 1020,
#     'estimate': '$44-55',
#     'currency_code': 'USD'}]},
#  {'place': 'Emory University',
#   'geometry': [33.7925239, -84.3261929],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 4.67,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 13.0,
#     'low_estimate': 9.0,
#     'duration': 1140,
#     'estimate': '$9-12',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 4.67,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 12.0,
#     'low_estimate': 9.0,
#     'duration': 1140,
#     'estimate': '$9-12',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 4.67,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 24.0,
#     'low_estimate': 18.0,
#     'duration': 1140,
#     'estimate': '$18-24',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 4.67,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 26.0,
#     'low_estimate': 20.0,
#     'duration': 1140,
#     'estimate': '$20-26',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 4.67,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 34.0,
#     'low_estimate': 27.0,
#     'duration': 1140,
#     'estimate': '$27-34',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 4.67,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 48.0,
#     'low_estimate': 38.0,
#     'duration': 1140,
#     'estimate': '$38-48',
#     'currency_code': 'USD'}]},
#  {'place': 'Georgia State University',
#   'geometry': [33.7530724, -84.3874759],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 3.05,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 600,
#     'estimate': '$6-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 3.05,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 600,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 3.05,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 17.0,
#     'low_estimate': 13.0,
#     'duration': 600,
#     'estimate': '$13-17',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 3.05,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 19.0,
#     'low_estimate': 14.0,
#     'duration': 600,
#     'estimate': '$14-19',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 3.05,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 24.0,
#     'low_estimate': 19.0,
#     'duration': 600,
#     'estimate': '$19-24',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 3.05,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 35.0,
#     'low_estimate': 28.0,
#     'duration': 600,
#     'estimate': '$28-35',
#     'currency_code': 'USD'}]},
#  {'place': 'Spelman College',
#   'geometry': [33.7463641, -84.4144874],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 4.72,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 11.0,
#     'low_estimate': 7.0,
#     'duration': 660,
#     'estimate': '$7-10',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 4.72,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 11.0,
#     'low_estimate': 8.0,
#     'duration': 660,
#     'estimate': '$8-11',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 4.72,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 21.0,
#     'low_estimate': 17.0,
#     'duration': 660,
#     'estimate': '$17-21',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 4.72,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 23.0,
#     'low_estimate': 18.0,
#     'duration': 660,
#     'estimate': '$18-23',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 4.72,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 31.0,
#     'low_estimate': 24.0,
#     'duration': 660,
#     'estimate': '$24-31',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 4.72,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 44.0,
#     'low_estimate': 35.0,
#     'duration': 660,
#     'estimate': '$35-44',
#     'currency_code': 'USD'}]},
#  {'place': 'Edgewood Bars',
#   'geometry': [33.7544814, -84.3745674],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 2.39,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 600,
#     'estimate': '$6-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 2.39,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 600,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 2.39,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 15.0,
#     'low_estimate': 12.0,
#     'duration': 600,
#     'estimate': '$12-15',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 2.39,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 17.0,
#     'low_estimate': 13.0,
#     'duration': 600,
#     'estimate': '$13-17',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 2.39,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 21.0,
#     'low_estimate': 17.0,
#     'duration': 600,
#     'estimate': '$17-21',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 2.39,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 32.0,
#     'low_estimate': 26.0,
#     'duration': 600,
#     'estimate': '$26-32',
#     'currency_code': 'USD'}]},
#  {'place': 'Hartsfield Jackson Airport',
#   'geometry': [33.6407282, -84.4277001],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 12.18,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 20.0,
#     'low_estimate': 15.0,
#     'duration': 1380,
#     'estimate': '$15-19',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 12.18,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 20.0,
#     'low_estimate': 15.0,
#     'duration': 1380,
#     'estimate': '$15-20',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 12.18,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 42.0,
#     'low_estimate': 33.0,
#     'duration': 1380,
#     'estimate': '$33-42',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 12.18,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 45.0,
#     'low_estimate': 36.0,
#     'duration': 1380,
#     'estimate': '$36-45',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 12.18,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 63.0,
#     'low_estimate': 51.0,
#     'duration': 1380,
#     'estimate': '$51-63',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 12.18,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 85.0,
#     'low_estimate': 68.0,
#     'duration': 1380,
#     'estimate': '$68-85',
#     'currency_code': 'USD'}]},
#  {'place': 'SunTrust Park',
#   'geometry': [33.8908211, -84.4678309],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 11.22,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 18.0,
#     'low_estimate': 13.0,
#     'duration': 1020,
#     'estimate': '$13-17',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 11.22,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 18.0,
#     'low_estimate': 14.0,
#     'duration': 1020,
#     'estimate': '$14-18',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 11.22,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 38.0,
#     'low_estimate': 30.0,
#     'duration': 1020,
#     'estimate': '$30-38',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 11.22,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 40.0,
#     'low_estimate': 32.0,
#     'duration': 1020,
#     'estimate': '$32-40',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 11.22,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 57.0,
#     'low_estimate': 46.0,
#     'duration': 1020,
#     'estimate': '$46-57',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 11.22,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 77.0,
#     'low_estimate': 62.0,
#     'duration': 1020,
#     'estimate': '$62-77',
#     'currency_code': 'USD'}]},
#  {'place': 'Mercedes Benz Stadium',
#   'geometry': [33.7554483, -84.400855],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 1.83,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 5.0,
#     'duration': 600,
#     'estimate': '$5-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 1.83,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 600,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 1.83,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 14.0,
#     'low_estimate': 11.0,
#     'duration': 600,
#     'estimate': '$11-14',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 1.83,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 16.0,
#     'low_estimate': 12.0,
#     'duration': 600,
#     'estimate': '$12-16',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 1.83,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 19.0,
#     'low_estimate': 15.0,
#     'duration': 600,
#     'estimate': '$15-19',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 1.83,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 30.0,
#     'low_estimate': 23.0,
#     'duration': 600,
#     'estimate': '$23-30',
#     'currency_code': 'USD'}]},
#  {'place': 'Lenox Square Mall',
#   'geometry': [33.8462925, -84.3621419],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 8.31,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 14.0,
#     'low_estimate': 10.0,
#     'duration': 960,
#     'estimate': '$10-13',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 8.31,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 14.0,
#     'low_estimate': 11.0,
#     'duration': 960,
#     'estimate': '$11-14',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 8.31,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 31.0,
#     'low_estimate': 24.0,
#     'duration': 960,
#     'estimate': '$24-31',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 8.31,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 33.0,
#     'low_estimate': 26.0,
#     'duration': 960,
#     'estimate': '$26-33',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 8.31,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 46.0,
#     'low_estimate': 37.0,
#     'duration': 960,
#     'estimate': '$37-46',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 8.31,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 63.0,
#     'low_estimate': 51.0,
#     'duration': 960,
#     'estimate': '$51-63',
#     'currency_code': 'USD'}]},
#  {'place': 'Piedmont Park',
#   'geometry': [33.7850856, -84.373803],
#   'autotime': '20: 13',
#   'time': '20:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 1.54,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 10.0,
#     'low_estimate': 6.0,
#     'duration': 600,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 1.54,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 600,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 1.54,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 13.0,
#     'low_estimate': 10.0,
#     'duration': 600,
#     'estimate': '$10-13',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 1.54,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 15.0,
#     'low_estimate': 12.0,
#     'duration': 600,
#     'estimate': '$12-15',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 1.54,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 18.0,
#     'low_estimate': 14.0,
#     'duration': 600,
#     'estimate': '$14-18',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 1.54,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 28.0,
#     'low_estimate': 22.0,
#     'duration': 600,
#     'estimate': '$22-28',
#     'currency_code': 'USD'}]}]

# %%
import json
with open('outfile.json', 'w') as outfile:
    json.dump(total_estimates, outfile)

# %%
from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
# Define our uberPrices table
class UberPrices(Base):
    __tablename__ = 'uberPrices'
    id = Column(Integer, primary_key=True)
    place = Column(String)
    lat = Column(Integer)
    lon = Column(Integer)
    dist = Column(Integer)
    display_name = Column(String)
    product_id = Column(String)
    duration = Column(Integer)
    estimate = Column(String)
    high_estimate = Column(Integer)
    low_estimate = Column(Integer)
    autotime = Column(String)
    time = Column(String)

# %%
# Right now, this table only exists in python and not in the actual database
# Base.metadata.tables

# %%
# Create our database engine
engine = create_engine('sqlite:///UberPrices.sqlite')

# %%
Base.metadata.create_all(engine)

# %%
# The ORM’s “handle” to the database is the Session.
from sqlalchemy.orm import Session
session = Session(engine)

# %%
# Note that adding to the session does not update the table. It queues up those queries.
for values in total_estimates:
    for value in values["value"]:
        session.add(UberPrices(place=values["place"], lat=values["geometry"][0], lon=values["geometry"][1], 
                               dist=value["distance"], display_name = value["display_name"], product_id = value["product_id"], 
                               duration = value["duration"], estimate = value["estimate"],
                               high_estimate = value["high_estimate"], low_estimate = value["low_estimate"],
                               autotime=values["autotime"], time=values["time"]
                              ))

# %%
# commit() flushes whatever remaining changes remain to the database, and commits the transaction.
session.commit()
